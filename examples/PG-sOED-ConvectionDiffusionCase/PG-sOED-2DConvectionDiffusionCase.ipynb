# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(os.path.dirname(current_dir))
sys.path.insert(0, parent_dir) 

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

from sOED import SOED
from sOED import PGsOED
from sOED.utils import *

conv_diff_nets = (torch.load("conv_diff_net_t0.05.pt"),
                  torch.load("conv_diff_net_t0.2.pt"))
def conv_diff_model(stage, theta, d, xp=None):
    """
    Convection diffusion model

    Parameters
    ----------
    stage : int
        The stage index of the experiment.
    theta : np.ndarray of size (n_sample or 1, n_param)
        The value of unknown linear model parameters.
    d : np.ndarray of size (n_sample or 1, n_design)
        The design variable.
    xp : np.ndarray of size (n_sample or 1, n_phys_state), 
         optional(default=None)
        The physical state.

    Returns
    -------
    numpy.ndarray of size (n_sample, n_obs)
        The output of the convection diffusion model.
    """
    n_sample = max(len(theta), len(d), len(xp))
    X = torch.zeros(n_sample, 4).double()
    X[:, :2] = torch.from_numpy(theta)
    X[:, 2:] = torch.from_numpy(xp + d)
    return conv_diff_nets[stage](X).detach().numpy()

def reward_fun(stage, xb, xp, d, y):
    """
    Non-KL-divergence based reward function g_k(x_k, d_k, y_k)
    
    Parameters
    ----------
    stage : int
        The stage index of the experiment.
    xb : numpy.ndarray of size (n_grid ** n_param, n_param + 1)
        Grid discritization of the belief state.
    xp : np.ndarray of size (n_phys_state)
        The physical state.
    d : np.ndarray of size (n_design)
        The design variable.
    y : np.ndarray of size (n_obs)
        The observation.

    Returns
    -------
    A float which is the reward.
    """
    if stage < n_stage:
        return 0
    else:
        return 0
    
def phys_state_fun(xp, stage, d, y):
    """
    Physical state transition function.
    x_{k+1,p} = phys_state_fun(x_{k,p}, d_k, y_k).
    
    Parameters
    ----------
    xp : np.ndarray of size (n_sample or 1, n_phys_state)
        The old physical state before conducting stage-th 
        experiement.
    stage : int
        The stage index of the experiment.
    d : np.ndarray of size (n_sample or 1, n_design)
        The design variables at stage-th experiment.
    y : np.ndarray of size (n_sample or 1, n_obs)
        The observations at stage-th expriments.
    
    Returns
    -------
    A numpy.ndarray of size (n_sample, n_xp)
    """
    return xp + d

# %%
n_stage = 2 # Number of stages.
n_param = 2 # Number of parameters.
n_design = 2 # Number of design variables.
n_obs = 1 # Number of observations.

prior_type = "uniform" # "normal" for normal dist, "uniform" for uniform dist.
prior_loc = 0 # mean for normal, lower bound for uniform.
prior_scale = 1 # std for normal, range for uniform.
prior_info = [(prior_type, prior_loc, prior_scale),
              (prior_type, prior_loc, prior_scale)]

design_bounds = [(-0.25, 0.25), (-0.25, 0.25)] # lower and upper bounds of design variables.

# Noise if following N(noise_loc, noise_base_scale + noise_ratio_scale * abs(G))
noise_loc = 0
noise_base_scale = 0.05
noise_ratio_scale = 0.05
noise_info = [(noise_loc, noise_base_scale, noise_ratio_scale),]

# Physical state info
n_phys_state = 2
init_phys_state = (0.5, 0.5)
phys_state_info = (n_phys_state, init_phys_state, phys_state_fun)

# Number of grid points on each dimension of parameter space to store PDFs.
n_grid = 50

# Method to sample posterior samples, could be "Rejection" or "MCMC", default
# is "MCMC".
post_rvs_method = "Rejection"


# Random state could be eith an integer or None.
random_state = 2021

# %%
soed = PGsOED(model_fun=conv_diff_model,
              n_stage=n_stage,
              n_param=n_param,
              n_design=n_design,
              n_obs=n_obs,
              prior_info=prior_info,
              design_bounds=design_bounds,
              noise_info=noise_info,
              reward_fun=reward_fun,
              phys_state_info=phys_state_info,
              n_grid=n_grid,
              post_rvs_method=post_rvs_method,
              random_state=random_state,
              actor_dimns=[80, 80],
              critic_dimns=[80, 80])

# %%
soed.initialize()
actor_optimizer = optim.Adam(soed.actor_net.parameters(), lr=0.01)
actor_lr_scheduler = optim.lr_scheduler.ExponentialLR(actor_optimizer, gamma=0.98)

n_critic_update = 100
critic_optimizer = optim.Adam(soed.critic_net.parameters(), lr=0.01)
critic_lr_scheduler = optim.lr_scheduler.ExponentialLR(critic_optimizer, gamma=0.98)

# %%
soed.soed(n_update=300,
          n_traj=1000,
          actor_optimizer=actor_optimizer,
          actor_lr_scheduler=actor_lr_scheduler,
          n_critic_update=n_critic_update,
          critic_optimizer=critic_optimizer,
          critic_lr_scheduler=critic_lr_scheduler,
          design_noise_scale=0.05, 
          design_noise_decay=0.99)
# Out:
# Update Level 0
# ******************************
# Averaged total reward:  1.159
# Update Level 1
# ******************************
# Averaged total reward:  1.137
# Update Level 2
# ******************************
# Averaged total reward:  1.196
# Update Level 3
# ******************************
# Averaged total reward:  1.199
# Update Level 4
# ******************************
# Averaged total reward:  1.237
# Update Level 5
# ******************************
# Averaged total reward:  1.239
# Update Level 6
# ******************************
# Averaged total reward:  1.266
# Update Level 7
# ******************************
# Averaged total reward:  1.266
# Update Level 8
# ******************************
# Averaged total reward:  1.239
# Update Level 9
# ******************************
# Averaged total reward:  1.25
# Update Level 10
# ******************************
# Averaged total reward:  1.314
# Update Level 11
# ******************************
# Averaged total reward:  1.261
# Update Level 12
# ******************************
# Averaged total reward:  1.284
# Update Level 13
# ******************************
# Averaged total reward:  1.293
# Update Level 14
# ******************************
# Averaged total reward:  1.306
# Update Level 15
# ******************************
# Averaged total reward:  1.323
# Update Level 16
# ******************************
# Averaged total reward:  1.295
# Update Level 17
# ******************************
# Averaged total reward:  1.263
# Update Level 18
# ******************************
# Averaged total reward:  1.313
# Update Level 19
# ******************************
# Averaged total reward:  1.27
# Update Level 20
# ******************************
# Averaged total reward:  1.287
# Update Level 21
# ******************************
# Averaged total reward:  1.292
# Update Level 22
# ******************************
# Averaged total reward:  1.308
# Update Level 23
# ******************************
# Averaged total reward:  1.312
# Update Level 24
# ******************************
# Averaged total reward:  1.309
# Update Level 25
# ******************************
# Averaged total reward:  1.313
# Update Level 26
# ******************************
# Averaged total reward:  1.23
# Update Level 27
# ******************************
# Averaged total reward:  1.253
# Update Level 28
# ******************************
# Averaged total reward:  1.292
# Update Level 29
# ******************************
# Averaged total reward:  1.255
# Update Level 30
# ******************************
# Averaged total reward:  1.327
# Update Level 31
# ******************************
# Averaged total reward:  1.284
# Update Level 32
# ******************************
# Averaged total reward:  1.266
# Update Level 33
# ******************************
# Averaged total reward:  1.263
# Update Level 34
# ******************************
# Averaged total reward:  1.286
# Update Level 35
# ******************************
# Averaged total reward:  1.301
# Update Level 36
# ******************************
# Averaged total reward:  1.298
# Update Level 37
# ******************************
# Averaged total reward:  1.292
# Update Level 38
# ******************************
# Averaged total reward:  1.316
# Update Level 39
# ******************************
# Averaged total reward:  1.308
# Update Level 40
# ******************************
# Averaged total reward:  1.259
# Update Level 41
# ******************************
# Averaged total reward:  1.284
# Update Level 42
# ******************************
# Averaged total reward:  1.294
# Update Level 43
# ******************************
# Averaged total reward:  1.314
# Update Level 44
# ******************************
# Averaged total reward:  1.271
# Update Level 45
# ******************************
# Averaged total reward:  1.289
# Update Level 46
# ******************************
# Averaged total reward:  1.284
# Update Level 47
# ******************************
# Averaged total reward:  1.265
# Update Level 48
# ******************************
# Averaged total reward:  1.31
# Update Level 49
# ******************************
# Averaged total reward:  1.284
# Update Level 50
# ******************************
# Averaged total reward:  1.292
# Update Level 51
# ******************************
# Averaged total reward:  1.314
# Update Level 52
# ******************************
# Averaged total reward:  1.319
# Update Level 53
# ******************************
# Averaged total reward:  1.307
# Update Level 54
# ******************************
# Averaged total reward:  1.307
# Update Level 55
# ******************************
# Averaged total reward:  1.286
# Update Level 56
# ******************************
# Averaged total reward:  1.307
# Update Level 57
# ******************************
# Averaged total reward:  1.295
# Update Level 58
# ******************************
# Averaged total reward:  1.3
# Update Level 59
# ******************************
# Averaged total reward:  1.287
# Update Level 60
# ******************************
# Averaged total reward:  1.299
# Update Level 61
# ******************************
# Averaged total reward:  1.316
# Update Level 62
# ******************************
# Averaged total reward:  1.276
# Update Level 63
# ******************************
# Averaged total reward:  1.279
# Update Level 64
# ******************************
# Averaged total reward:  1.31
# Update Level 65
# ******************************
# Averaged total reward:  1.311
# Update Level 66
# ******************************
# Averaged total reward:  1.372
# Update Level 67
# ******************************
# Averaged total reward:  1.281
# Update Level 68
# ******************************
# Averaged total reward:  1.28
# Update Level 69
# ******************************
# Averaged total reward:  1.283
# Update Level 70
# ******************************
# Averaged total reward:  1.293
# Update Level 71
# ******************************
# Averaged total reward:  1.305
# Update Level 72
# ******************************
# Averaged total reward:  1.307
# Update Level 73
# ******************************
# Averaged total reward:  1.368
# Update Level 74
# ******************************
# Averaged total reward:  1.299
# Update Level 75
# ******************************
# Averaged total reward:  1.329
# Update Level 76
# ******************************
# Averaged total reward:  1.338
# Update Level 77
# ******************************
# Averaged total reward:  1.3
# Update Level 78
# ******************************
# Averaged total reward:  1.317
# Update Level 79
# ******************************
# Averaged total reward:  1.324
# Update Level 80
# ******************************
# Averaged total reward:  1.309
# Update Level 81
# ******************************
# Averaged total reward:  1.316
# Update Level 82
# ******************************
# Averaged total reward:  1.327
# Update Level 83
# ******************************
# Averaged total reward:  1.304
# Update Level 84
# ******************************
# Averaged total reward:  1.294
# Update Level 85
# ******************************
# Averaged total reward:  1.311
# Update Level 86
# ******************************
# Averaged total reward:  1.309
# Update Level 87
# ******************************
# Averaged total reward:  1.314
# Update Level 88
# ******************************
# Averaged total reward:  1.343
# Update Level 89
# ******************************
# Averaged total reward:  1.319
# Update Level 90
# ******************************
# Averaged total reward:  1.309
# Update Level 91
# ******************************
# Averaged total reward:  1.365
# Update Level 92
# ******************************
# Averaged total reward:  1.324
# Update Level 93
# ******************************
# Averaged total reward:  1.345
# Update Level 94
# ******************************
# Averaged total reward:  1.302
# Update Level 95
# ******************************
# Averaged total reward:  1.301
# Update Level 96
# ******************************
# Averaged total reward:  1.303
# Update Level 97
# ******************************
# Averaged total reward:  1.294
# Update Level 98
# ******************************
# Averaged total reward:  1.327
# Update Level 99
# ******************************
# Averaged total reward:  1.305
# Update Level 100
# ******************************
# Averaged total reward:  1.347
# Update Level 101
# ******************************
# Averaged total reward:  1.305
# Update Level 102
# ******************************
# Averaged total reward:  1.265
# Update Level 103
# ******************************
# Averaged total reward:  1.355
# Update Level 104
# ******************************
# Averaged total reward:  1.328
# Update Level 105
# ******************************
# Averaged total reward:  1.295
# Update Level 106
# ******************************
# Averaged total reward:  1.291
# Update Level 107
# ******************************
# Averaged total reward:  1.346
# Update Level 108
# ******************************
# Averaged total reward:  1.338
# Update Level 109
# ******************************
# Averaged total reward:  1.282
# Update Level 110
# ******************************
# Averaged total reward:  1.334
# Update Level 111
# ******************************
# Averaged total reward:  1.331
# Update Level 112
# ******************************
# Averaged total reward:  1.318
# Update Level 113
# ******************************
# Averaged total reward:  1.355
# Update Level 114
# ******************************
# Averaged total reward:  1.315
# Update Level 115
# ******************************
# Averaged total reward:  1.333
# Update Level 116
# ******************************
# Averaged total reward:  1.33
# Update Level 117
# ******************************
# Averaged total reward:  1.308
# Update Level 118
# ******************************
# Averaged total reward:  1.298
# Update Level 119
# ******************************
# Averaged total reward:  1.295
# Update Level 120
# ******************************
# Averaged total reward:  1.366
# Update Level 121
# ******************************
# Averaged total reward:  1.321
# Update Level 122
# ******************************
# Averaged total reward:  1.318
# Update Level 123
# ******************************
# Averaged total reward:  1.306
# Update Level 124
# ******************************
# Averaged total reward:  1.318
# Update Level 125
# ******************************
# Averaged total reward:  1.335
# Update Level 126
# ******************************
# Averaged total reward:  1.338
# Update Level 127
# ******************************
# Averaged total reward:  1.395
# Update Level 128
# ******************************
# Averaged total reward:  1.283
# Update Level 129
# ******************************
# Averaged total reward:  1.309
# Update Level 130
# ******************************
# Averaged total reward:  1.332
# Update Level 131
# ******************************
# Averaged total reward:  1.303
# Update Level 132
# ******************************
# Averaged total reward:  1.334
# Update Level 133
# ******************************
# Averaged total reward:  1.34
# Update Level 134
# ******************************
# Averaged total reward:  1.316
# Update Level 135
# ******************************
# Averaged total reward:  1.336
# Update Level 136
# ******************************
# Averaged total reward:  1.305
# Update Level 137
# ******************************
# Averaged total reward:  1.339
# Update Level 138
# ******************************
# Averaged total reward:  1.319
# Update Level 139
# ******************************
# Averaged total reward:  1.295
# Update Level 140
# ******************************
# Averaged total reward:  1.369
# Update Level 141
# ******************************
# Averaged total reward:  1.318
# Update Level 142
# ******************************
# Averaged total reward:  1.355
# Update Level 143
# ******************************
# Averaged total reward:  1.303
# Update Level 144
# ******************************
# Averaged total reward:  1.327
# Update Level 145
# ******************************
# Averaged total reward:  1.327
# Update Level 146
# ******************************
# Averaged total reward:  1.314
# Update Level 147
# ******************************
# Averaged total reward:  1.327
# Update Level 148
# ******************************
# Averaged total reward:  1.301
# Update Level 149
# ******************************
# Averaged total reward:  1.317
# Update Level 150
# ******************************
# Averaged total reward:  1.309
# Update Level 151
# ******************************
# Averaged total reward:  1.312
# Update Level 152
# ******************************
# Averaged total reward:  1.34
# Update Level 153
# ******************************
# Averaged total reward:  1.279
# Update Level 154
# ******************************
# Averaged total reward:  1.343
# Update Level 155
# ******************************
# Averaged total reward:  1.303
# Update Level 156
# ******************************
# Averaged total reward:  1.296
# Update Level 157
# ******************************
# Averaged total reward:  1.335
# Update Level 158
# ******************************
# Averaged total reward:  1.32
# Update Level 159
# ******************************
# Averaged total reward:  1.346
# Update Level 160
# ******************************
# Averaged total reward:  1.328
# Update Level 161
# ******************************
# Averaged total reward:  1.336
# Update Level 162
# ******************************
# Averaged total reward:  1.324
# Update Level 163
# ******************************
# Averaged total reward:  1.363
# Update Level 164
# ******************************
# Averaged total reward:  1.313
# Update Level 165
# ******************************
# Averaged total reward:  1.296
# Update Level 166
# ******************************
# Averaged total reward:  1.317
# Update Level 167
# ******************************
# Averaged total reward:  1.275
# Update Level 168
# ******************************
# Averaged total reward:  1.314
# Update Level 169
# ******************************
# Averaged total reward:  1.352
# Update Level 170
# ******************************
# Averaged total reward:  1.364
# Update Level 171
# ******************************
# Averaged total reward:  1.284
# Update Level 172
# ******************************
# Averaged total reward:  1.307
# Update Level 173
# ******************************
# Averaged total reward:  1.304
# Update Level 174
# ******************************
# Averaged total reward:  1.331
# Update Level 175
# ******************************
# Averaged total reward:  1.319
# Update Level 176
# ******************************
# Averaged total reward:  1.324
# Update Level 177
# ******************************
# Averaged total reward:  1.352
# Update Level 178
# ******************************
# Averaged total reward:  1.329
# Update Level 179
# ******************************
# Averaged total reward:  1.332
# Update Level 180
# ******************************
# Averaged total reward:  1.326
# Update Level 181
# ******************************
# Averaged total reward:  1.331
# Update Level 182
# ******************************
# Averaged total reward:  1.288
# Update Level 183
# ******************************
# Averaged total reward:  1.268
# Update Level 184
# ******************************
# Averaged total reward:  1.304
# Update Level 185
# ******************************
# Averaged total reward:  1.357
# Update Level 186
# ******************************
# Averaged total reward:  1.342
# Update Level 187
# ******************************
# Averaged total reward:  1.362
# Update Level 188
# ******************************
# Averaged total reward:  1.32
# Update Level 189
# ******************************
# Averaged total reward:  1.385
# Update Level 190
# ******************************
# Averaged total reward:  1.395
# Update Level 191
# ******************************
# Averaged total reward:  1.328
# Update Level 192
# ******************************
# Averaged total reward:  1.35
# Update Level 193
# ******************************
# Averaged total reward:  1.325
# Update Level 194
# ******************************
# Averaged total reward:  1.345
# Update Level 195
# ******************************
# Averaged total reward:  1.307
# Update Level 196
# ******************************
# Averaged total reward:  1.348
# Update Level 197
# ******************************
# Averaged total reward:  1.347
# Update Level 198
# ******************************
# Averaged total reward:  1.277
# Update Level 199
# ******************************
# Averaged total reward:  1.322
# Update Level 200
# ******************************
# Averaged total reward:  1.359
# Update Level 201
# ******************************
# Averaged total reward:  1.344
# Update Level 202
# ******************************
# Averaged total reward:  1.371
# Update Level 203
# ******************************
# Averaged total reward:  1.309
# Update Level 204
# ******************************
# Averaged total reward:  1.331
# Update Level 205
# ******************************
# Averaged total reward:  1.294
# Update Level 206
# ******************************
# Averaged total reward:  1.361
# Update Level 207
# ******************************
# Averaged total reward:  1.337
# Update Level 208
# ******************************
# Averaged total reward:  1.341
# Update Level 209
# ******************************
# Averaged total reward:  1.336
# Update Level 210
# ******************************
# Averaged total reward:  1.333
# Update Level 211
# ******************************
# Averaged total reward:  1.339
# Update Level 212
# ******************************
# Averaged total reward:  1.349
# Update Level 213
# ******************************
# Averaged total reward:  1.328
# Update Level 214
# ******************************
# Averaged total reward:  1.329
# Update Level 215
# ******************************
# Averaged total reward:  1.359
# Update Level 216
# ******************************
# Averaged total reward:  1.317
# Update Level 217
# ******************************
# Averaged total reward:  1.339
# Update Level 218
# ******************************
# Averaged total reward:  1.295
# Update Level 219
# ******************************
# Averaged total reward:  1.374
# Update Level 220
# ******************************
# Averaged total reward:  1.342
# Update Level 221
# ******************************
# Averaged total reward:  1.299
# Update Level 222
# ******************************
# Averaged total reward:  1.328
# Update Level 223
# ******************************
# Averaged total reward:  1.311
# Update Level 224
# ******************************
# Averaged total reward:  1.333
# Update Level 225
# ******************************
# Averaged total reward:  1.311
# Update Level 226
# ******************************
# Averaged total reward:  1.33
# Update Level 227
# ******************************
# Averaged total reward:  1.323
# Update Level 228
# ******************************
# Averaged total reward:  1.307
# Update Level 229
# ******************************
# Averaged total reward:  1.29
# Update Level 230
# ******************************
# Averaged total reward:  1.388
# Update Level 231
# ******************************
# Averaged total reward:  1.322
# Update Level 232
# ******************************
# Averaged total reward:  1.354
# Update Level 233
# ******************************
# Averaged total reward:  1.315
# Update Level 234
# ******************************
# Averaged total reward:  1.345
# Update Level 235
# ******************************
# Averaged total reward:  1.33
# Update Level 236
# ******************************
# Averaged total reward:  1.298
# Update Level 237
# ******************************
# Averaged total reward:  1.271
# Update Level 238
# ******************************
# Averaged total reward:  1.332
# Update Level 239
# ******************************
# Averaged total reward:  1.347
# Update Level 240
# ******************************
# Averaged total reward:  1.275
# Update Level 241
# ******************************
# Averaged total reward:  1.361
# Update Level 242
# ******************************
# Averaged total reward:  1.285
# Update Level 243
# ******************************
# Averaged total reward:  1.295
# Update Level 244
# ******************************
# Averaged total reward:  1.317
# Update Level 245
# ******************************
# Averaged total reward:  1.31
# Update Level 246
# ******************************
# Averaged total reward:  1.283
# Update Level 247
# ******************************
# Averaged total reward:  1.35
# Update Level 248
# ******************************
# Averaged total reward:  1.304
# Update Level 249
# ******************************
# Averaged total reward:  1.297
# Update Level 250
# ******************************
# Averaged total reward:  1.298
# Update Level 251
# ******************************
# Averaged total reward:  1.339
# Update Level 252
# ******************************
# Averaged total reward:  1.349
# Update Level 253
# ******************************
# Averaged total reward:  1.311
# Update Level 254
# ******************************
# Averaged total reward:  1.36
# Update Level 255
# ******************************
# Averaged total reward:  1.318
# Update Level 256
# ******************************
# Averaged total reward:  1.388
# Update Level 257
# ******************************
# Averaged total reward:  1.378
# Update Level 258
# ******************************
# Averaged total reward:  1.323
# Update Level 259
# ******************************
# Averaged total reward:  1.342
# Update Level 260
# ******************************
# Averaged total reward:  1.34
# Update Level 261
# ******************************
# Averaged total reward:  1.36
# Update Level 262
# ******************************
# Averaged total reward:  1.372
# Update Level 263
# ******************************
# Averaged total reward:  1.373
# Update Level 264
# ******************************
# Averaged total reward:  1.297
# Update Level 265
# ******************************
# Averaged total reward:  1.334
# Update Level 266
# ******************************
# Averaged total reward:  1.317
# Update Level 267
# ******************************
# Averaged total reward:  1.343
# Update Level 268
# ******************************
# Averaged total reward:  1.365
# Update Level 269
# ******************************
# Averaged total reward:  1.358
# Update Level 270
# ******************************
# Averaged total reward:  1.299
# Update Level 271
# ******************************
# Averaged total reward:  1.297
# Update Level 272
# ******************************
# Averaged total reward:  1.314
# Update Level 273
# ******************************
# Averaged total reward:  1.297
# Update Level 274
# ******************************
# Averaged total reward:  1.312
# Update Level 275
# ******************************
# Averaged total reward:  1.311
# Update Level 276
# ******************************
# Averaged total reward:  1.335
# Update Level 277
# ******************************
# Averaged total reward:  1.323
# Update Level 278
# ******************************
# Averaged total reward:  1.284
# Update Level 279
# ******************************
# Averaged total reward:  1.334
# Update Level 280
# ******************************
# Averaged total reward:  1.322
# Update Level 281
# ******************************
# Averaged total reward:  1.351
# Update Level 282
# ******************************
# Averaged total reward:  1.348
# Update Level 283
# ******************************
# Averaged total reward:  1.305
# Update Level 284
# ******************************
# Averaged total reward:  1.325
# Update Level 285
# ******************************
# Averaged total reward:  1.368
# Update Level 286
# ******************************
# Averaged total reward:  1.305
# Update Level 287
# ******************************
# Averaged total reward:  1.317
# Update Level 288
# ******************************
# Averaged total reward:  1.362
# Update Level 289
# ******************************
# Averaged total reward:  1.33
# Update Level 290
# ******************************
# Averaged total reward:  1.304
# Update Level 291
# ******************************
# Averaged total reward:  1.324
# Update Level 292
# ******************************
# Averaged total reward:  1.334
# Update Level 293
# ******************************
# Averaged total reward:  1.3
# Update Level 294
# ******************************
# Averaged total reward:  1.284
# Update Level 295
# ******************************
# Averaged total reward:  1.305
# Update Level 296
# ******************************
# Averaged total reward:  1.322
# Update Level 297
# ******************************
# Averaged total reward:  1.315
# Update Level 298
# ******************************
# Averaged total reward:  1.301
# Update Level 299
# ******************************
# Averaged total reward:  1.301

# %%
soed.asses(10000)
# Out:
# ******************************
# Averaged total reward:  1.335
# 1.335173376084874

# %%
plt.figure(figsize=(10,6))
bins = np.linspace(0, 6, 100)
plt.hist(soed.rewards_hist.sum(-1), alpha=0.5, bins=bins, color='c', 
         label='PG-sOED')
plt.xlim(0, 6)
plt.legend(fontsize=20)
plt.xlabel('Reward', fontsize=25)
plt.ylabel('Counts', fontsize=25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 5))
for k in range(2):
    plt.subplot(1, 2, k + 1)
    plt.scatter(soed.dcs_hist[:, k, 0], soed.dcs_hist[:, k, 1])
    plt.xlim(-0.3, 0.3)
    plt.ylim(-0.3, 0.3)
    plt.xlabel("$d_0$", fontsize=20)
    plt.ylabel("$d_1$", fontsize=20)
    plt.grid(ls='--')
    plt.title(f"{k}-th stage", fontsize=25)

# %%
# np.random.seed(112)
plt.figure(figsize=(11, 4))
x = np.linspace(0, 1, 50)
y = x
X, Y = np.meshgrid(x, y)
theta = np.random.random(size=2)
theta = np.array([0.65, 0.7])
d_hist = np.zeros((soed.n_stage, soed.n_design))
y_hist = np.zeros((soed.n_stage, soed.n_obs))
xp = np.array(soed.init_xp)
reward_hist = np.zeros(soed.n_stage + 1)
xb = soed.get_xb(None)
levels = None
for i in range(soed.n_stage + 1):
    if i > 0:
        xb = soed.get_xb(d_hist=d_hist[:i], y_hist=y_hist[:i])
        plt.subplot(1, 2, i, aspect='equal')
        plt.contourf(xb[:, 0].reshape(n_grid, n_grid),
                     xb[:, 1].reshape(n_grid, n_grid),
                     xb[:, -1].reshape(n_grid, n_grid), 
                     cmap='viridis', 
                     levels=levels)
        if i == n_stage:
            cbar = plt.colorbar()
            cbar.ax.tick_params(labelsize=15)
        plt.title(f"$p(\\theta|I_{i})$", fontsize=25, pad=10)
        plt.scatter(theta[0], theta[1], marker='*', s=300, c='magenta')
        plt.scatter(xp[0], xp[1], marker='o', s=300, c='orangered')
        plt.arrow(xp[0] - d_hist[i - 1, 0],
                  xp[1] - d_hist[i - 1, 1],
                  d_hist[i - 1, 0],
                  d_hist[i - 1, 1], 
                  color='orangered')
        plt.xlim(0, 1)
        plt.ylim(0, 1)
        plt.xticks(np.linspace(0, 1, 6), fontsize=15)
        plt.yticks(np.linspace(0, 1, 6), fontsize=15)
        plt.xlabel('$z_x$', fontsize=20)
        if i == 1:
            plt.ylabel('$z_y$', fontsize=20)
        plt.grid(which='both', ls='--')
        plt.subplots_adjust(wspace=0.05)
    if i < soed.n_stage:
        d_hist[i] = soed.get_design(i,
                                    d_hist=d_hist[:i], 
                                    y_hist=y_hist[:i])
        G = soed.m_f(i, theta.reshape(1, -1),
                     d_hist[i].reshape(1, -1), xp.reshape(1, -1)).flatten()
        y_hist[i] = np.random.normal(loc=G + 0 * noise_loc,
                                     scale=0 * soed.noise_b_s + 
                                     0 * soed.noise_r_s * np.abs(G))
        xp = soed.xp_f(xp, i, d_hist[i], y_hist[i])
    
    if i == soed.n_stage:
        d_in = None
        y_in = None
    else:
        d_in = d_hist[i]
        y_in = y_hist[i]
    reward_hist[i] = soed.get_reward(i, xb, xp, d_in, y_in)
print ('reward:', reward_hist.sum())
# Out:
# reward: 3.6044012614056835
